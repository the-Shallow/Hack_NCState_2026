# %%
import importlib
import json
from dataclasses import asdict
import post_classifier

importlib.reload(post_classifier)
extract_post_text_for_llm = post_classifier.extract_post_text_for_llm
result = extract_post_text_for_llm(
    "https://scontent-iad3-2.cdninstagram.com/v/t51.82787-15/631977322_18560622514037069_8481758575948466316_n.jpg?stp=dst-jpg_e35_tt6&_nc_cat=1&ig_cache_key=MzgzMTg4NDk0NDk4NjIxOTA5NQ%3D%3D.3-ccb7-5&ccb=7-5&_nc_sid=58cdad&efg=eyJ2ZW5jb2RlX3RhZyI6InhwaWRzLjEzNDl4MTc5OS5zZHIuQzMifQ%3D%3D&_nc_ohc=mPJUE-2G1KIQ7kNvwEnkwth&_nc_oc=AdkwrOfKSPzIgAGjVGcCG4AY7jnNlSMUr_j5MyNVOi09uvhDfNJbvNQwu74jo0EUWzo&_nc_ad=z-m&_nc_cid=0&_nc_zt=23&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_gid=SWym-XPXowlGuft38yNd5Q&oh=00_AfvmG3QtMGPJHo9lIgpPLrwVPMYm1Sjnyb06V-GDcIc2Sg&oe=6996D28B"
)
print(json.dumps(asdict(result), indent=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       6 extract_post_text_for_llm = post_classifier.extract_post_text_for_llm
#       7 result = extract_post_text_for_llm(
#       8     "https://scontent-iad3-2.cdninstagram.com/v/t51.82787-15/631977322_18560622514037069_8481758575948466316_n.jpg?stp=dst-jpg_e35_tt6&_nc_cat=1&ig_cache_key=MzgzMTg4NDk0NDk4NjIxOTA5NQ%3D%3D.3-ccb7-5&ccb=7-5&_nc_sid=58cdad&efg=eyJ2ZW5jb2RlX3RhZyI6InhwaWRzLjEzNDl4MTc5OS5zZHIuQzMifQ%3D%3D&_nc_ohc=mPJUE-2G1KIQ7kNvwEnkwth&_nc_oc=AdkwrOfKSPzIgAGjVGcCG4AY7jnNlSMUr_j5MyNVOi09uvhDfNJbvNQwu74jo0EUWzo&_nc_ad=z-m&_nc_cid=0&_nc_zt=23&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_gid=SWym-XPXowlGuft38yNd5Q&oh=00_AfvmG3QtMGPJHo9lIgpPLrwVPMYm1Sjnyb06V-GDcIc2Sg&oe=6996D28B"
#       9 )
# ---> 10 print(json.dumps(result, indent=2))
#
# ...
