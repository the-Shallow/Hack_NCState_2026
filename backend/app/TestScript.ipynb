# %%
import importlib
import json
import post_classifier

importlib.reload(post_classifier)
extract_post_text_for_llm = post_classifier.extract_post_text_for_llm
result = extract_post_text_for_llm(
    "https://scontent-iad3-2.cdninstagram.com/v/t51.82787-15/633472508_18093751214512535_5732113002288729679_n.jpg?stp=dst-jpg_e35_tt6&_nc_cat=1&ig_cache_key=MzgzMjQ3OTc1NDg0NzI2MTY1MQ%3D%3D.3-ccb7-5&ccb=7-5&_nc_sid=58cdad&efg=eyJ2ZW5jb2RlX3RhZyI6InhwaWRzLjE0NDB4MTgwMS5zZHIuQzMifQ%3D%3D&_nc_ohc=Qav97D2jKvIQ7kNvwGMQzi9&_nc_oc=Adlr9VQAC-kncXA2mrQLDq-DqSd1Af-kheffE6Nh9cI_Qaw_ZAg3Vj3OMxcTiPEHQLw&_nc_ad=z-m&_nc_cid=0&_nc_zt=23&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_gid=E4jGdQlt1VSxZsF9p4U5cw&oh=00_Afu2jJSNQG8aWJOuCcea3gLClMXJZa-4_FqGxFMGkA5tYA&oe=6996DAFE",
    caption="",
    alt_text="",
)
print(json.dumps(result, indent=2))
# Out:
# {
#   "llm-input-text": "Nessagsit\u201d\nee y/ (Ae tat, Pr eon EEN\n~ WARNING: SOME CREEPY\nRUNNING THE WORLD\u201d\n\u201c WARHING: SOME GREEPY\nFIGURES ON AN ISLAND ARE SECRETLY",
#   "caption": "",
#   "alt-text": ""
# }
